-- %% [markdown]
-- # Superstore Sales & Profit Analysis Using SQL

-- %%
/*superstore data from kaggle*/
select * from `workspace`.`default`.`sample_superstore` limit 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Row ID</th><th>Order ID</th><th>Order Date</th><th>Ship Date</th><th>Ship Mode</th><th>Customer ID</th><th>Customer Name</th><th>Segment</th><th>Country</th><th>City</th><th>State</th><th>Postal Code</th><th>Region</th><th>Product ID</th><th>Category</th><th>Sub-Category</th><th>Product Name</th><th>Sales</th><th>Quantity</th><th>Discount</th><th>Profit</th></tr></thead><tbody><tr><td>1</td><td>CA-2016-152156</td><td>2016-11-08</td><td>2016-11-11</td><td>Second Class</td><td>CG-12520</td><td>Claire Gute</td><td>Consumer</td><td>United States</td><td>Henderson</td><td>Kentucky</td><td>42420</td><td>South</td><td>FUR-BO-10001798</td><td>Furniture</td><td>Bookcases</td><td>Bush Somerset Collection Bookcase</td><td>261.96</td><td>2</td><td>0.0</td><td>41.9136</td></tr><tr><td>2</td><td>CA-2016-152156</td><td>2016-11-08</td><td>2016-11-11</td><td>Second Class</td><td>CG-12520</td><td>Claire Gute</td><td>Consumer</td><td>United States</td><td>Henderson</td><td>Kentucky</td><td>42420</td><td>South</td><td>FUR-CH-10000454</td><td>Furniture</td><td>Chairs</td><td>Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back</td><td>731.94</td><td>3</td><td>0.0</td><td>219.582</td></tr><tr><td>3</td><td>CA-2016-138688</td><td>2016-06-12</td><td>2016-06-16</td><td>Second Class</td><td>DV-13045</td><td>Darrin Van Huff</td><td>Corporate</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90036</td><td>West</td><td>OFF-LA-10000240</td><td>Office Supplies</td><td>Labels</td><td>Self-Adhesive Address Labels for Typewriters by Universal</td><td>14.62</td><td>2</td><td>0.0</td><td>6.8714</td></tr><tr><td>4</td><td>US-2015-108966</td><td>2015-10-11</td><td>2015-10-18</td><td>Standard Class</td><td>SO-20335</td><td>Sean O'Donnell</td><td>Consumer</td><td>United States</td><td>Fort Lauderdale</td><td>Florida</td><td>33311</td><td>South</td><td>FUR-TA-10000577</td><td>Furniture</td><td>Tables</td><td>Bretford CR4500 Series Slim Rectangular Table</td><td>957.5775</td><td>5</td><td>0.45</td><td>-383.031</td></tr><tr><td>5</td><td>US-2015-108966</td><td>2015-10-11</td><td>2015-10-18</td><td>Standard Class</td><td>SO-20335</td><td>Sean O'Donnell</td><td>Consumer</td><td>United States</td><td>Fort Lauderdale</td><td>Florida</td><td>33311</td><td>South</td><td>OFF-ST-10000760</td><td>Office Supplies</td><td>Storage</td><td>Eldon Fold 'N Roll Cart System</td><td>22.368</td><td>2</td><td>0.2</td><td>2.5164</td></tr><tr><td>6</td><td>CA-2014-115812</td><td>2014-06-09</td><td>2014-06-14</td><td>Standard Class</td><td>BH-11710</td><td>Brosina Hoffman</td><td>Consumer</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90032</td><td>West</td><td>FUR-FU-10001487</td><td>Furniture</td><td>Furnishings</td><td>Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood</td><td>48.86</td><td>7</td><td>0.0</td><td>14.1694</td></tr><tr><td>7</td><td>CA-2014-115812</td><td>2014-06-09</td><td>2014-06-14</td><td>Standard Class</td><td>BH-11710</td><td>Brosina Hoffman</td><td>Consumer</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90032</td><td>West</td><td>OFF-AR-10002833</td><td>Office Supplies</td><td>Art</td><td>Newell 322</td><td>7.28</td><td>4</td><td>0.0</td><td>1.9656</td></tr><tr><td>8</td><td>CA-2014-115812</td><td>2014-06-09</td><td>2014-06-14</td><td>Standard Class</td><td>BH-11710</td><td>Brosina Hoffman</td><td>Consumer</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90032</td><td>West</td><td>TEC-PH-10002275</td><td>Technology</td><td>Phones</td><td>Mitel 5320 IP Phone VoIP phone</td><td>907.152</td><td>6</td><td>0.2</td><td>90.7152</td></tr><tr><td>9</td><td>CA-2014-115812</td><td>2014-06-09</td><td>2014-06-14</td><td>Standard Class</td><td>BH-11710</td><td>Brosina Hoffman</td><td>Consumer</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90 ...

-- %% [markdown]
-- ## Total Sales and Profit

-- %%
SELECT
    ROUND(SUM(Sales), 2) AS total_sales,
    ROUND(SUM(Profit), 2) AS total_profit
FROM `workspace`.`default`.`sample_superstore`;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_sales</th><th>total_profit</th></tr></thead><tbody><tr><td>2297200.86</td><td>286397.02</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Top 10 Most Profitable transactions

-- %%
SELECT 
    `Product Name`,
    ROUND(SUM(Profit), 2) AS total_profit
FROM `workspace`.`default`.`sample_superstore`
GROUP BY `Product Name`
ORDER BY total_profit DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product Name</th><th>total_profit</th></tr></thead><tbody><tr><td>Canon imageCLASS 2200 Advanced Copier</td><td>25199.93</td></tr><tr><td>Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind</td><td>7753.04</td></tr><tr><td>Hewlett Packard LaserJet 3310 Copier</td><td>6983.88</td></tr><tr><td>Canon PC1060 Personal Laser Copier</td><td>4570.93</td></tr><tr><td>HP Designjet T520 Inkjet Large Format Printer - 24" Color</td><td>4094.98</td></tr><tr><td>Ativa V4110MDD Micro-Cut Shredder</td><td>3772.95</td></tr><tr><td>3D Systems Cube Printer, 2nd Generation, Magenta</td><td>3717.97</td></tr><tr><td>Plantronics Savi W720 Multi-Device Wireless Headset System</td><td>3696.28</td></tr><tr><td>Ibico EPK-21 Electric Binding System</td><td>3345.28</td></tr><tr><td>Zebra ZM400 Thermal Label Printer</td><td>3343.54</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT 
    Region,
    ROUND(SUM(Profit), 2) AS total_profit
FROM `workspace`.`default`.`sample_superstore`
GROUP BY Region
ORDER BY total_profit DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Region</th><th>total_profit</th></tr></thead><tbody><tr><td>West</td><td>108418.45</td></tr><tr><td>East</td><td>91522.78</td></tr><tr><td>South</td><td>46749.43</td></tr><tr><td>Central</td><td>39706.36</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT 
    DATE_TRUNC('month', `Order Date`) AS month,
    ROUND(SUM(Sales), 2) AS monthly_sales
FROM `workspace`.`default`.`sample_superstore`
GROUP BY month
ORDER BY month;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th
td>52981.73</td></tr><tr><td>2017-07-01T00:00:00.000Z</td><td>45264.42</td></tr><tr><td>2017-08-01T00:00:00.000Z</td><td>63120.89</td></tr><tr><td>2017-09-01T00:00:00.000Z</td><td>87866.65</td></tr><tr><td>2017-10-01T00:00:00.000Z</td><td>77776.92</td></tr><tr><td>2017-11-01T00:00:00.000Z</td><td>118447.83</td></tr><tr><td>2017-12-01T00:00:00.000Z</td><td>83829.32</td></tr></tbody></table></div>

-- %%
SELECT 
    Segment,
    ROUND(SUM(Sales), 2) AS segment_sales,
    ROUND(SUM(Profit), 2) AS segment_profit
FROM `workspace`.`default`.`sample_superstore`
GROUP BY Segment
ORDER BY segment_profit DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Segment</th><th>segment_sales</th><th>segment_profit</th></tr></thead><tbody><tr><td>Consumer</td><td>1161401.34</td><td>134119.21</td></tr><tr><td>Corporate</td><td>706146.37</td><td>91979.13</td></tr><tr><td>Home Office</td><td>429653.15</td><td>60298.68</td></tr></tbody></table></div>

-- %%
SELECT
  Category,
  SUM(Sales) AS total_sales
FROM `workspace`.`default`.`sample_superstore`
GROUP BY Category
ORDER BY total_sales DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>total_sales</th></tr></thead><tbody><tr><td>Technology</td><td>836154.0329999966</td></tr><tr><td>Furniture</td><td>741999.7952999998</td></tr><tr><td>Office Supplies</td><td>719047.0320000029</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## Monthly Sales

-- %%
SELECT 
    DATE_TRUNC('month', `Order Date`) AS month,
    SUM(Sales) AS monthly_sales
FROM `workspace`.`default`.`sample_superstore`
GROUP BY month
ORDER BY month;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>monthly_sales</th></tr></thead><tbody><tr><td>2014-01-01T00:00:00.000Z</td><td>14236.894999999997</td></tr><tr><td>2014-02-01T00:00:00.000Z</td><td>4519.892</td></tr><tr><td>2014-03-01T00:00:00.000Z</td><td>55691.00900000003</td></tr><tr><td>2014-04-01T00:00:00.000Z</td><td>28295.344999999994</td></tr><tr><td>2014-05-01T00:00:00.000Z</td><td>23648.287</td></tr><tr><td>2014-06-01T00:00:00.000Z</td><td>34595.12760000003</td></tr><tr><td>2014-07-01T00:00:00.000Z</td><td>33946.393</td></tr><tr><td>2014-08-01T00:00:00.000Z</td><td>27909.46849999999</td></tr><tr><td>2014-09-01T00:00:00.000Z</td><td>81777.35079999997</td></tr><tr><td>2014-10-01T00:00:00.000Z</td><td>31453.39299999999</td></tr><tr><td>2014-11-01T00:00:00.000Z</td><td>78628.71669999999</td></tr><tr><td>2014-12-01T00:00:00.000Z</td><td>69545.62049999999</td></tr><tr><td>2015-01-01T00: